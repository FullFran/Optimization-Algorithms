# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display, clear_output

# %%
def E_particula(n):
    '''
    Definimos la energía de una partícula, dada por la energía del oscilador armónico cuántico
    esta es E = (n + 1/2) hbar * omega
    '''
    return (n + 1/2)

def E_Total(particulas):
    '''
    Definimos la energía total de un sistema de N partículas independientes
    '''
    for i in range(len(particulas)):
        E = E_particula(i)*particulas[i]
    return E

def metropolis(T, n_pasos, n_max = 1000):
    '''
    Definimos la función metropolis

    '''
    # Definimos el estado inicial, con un array de longitud n_max
    # con el número de partículas en cada estado originiralmente
    # el mismo en cada estado.
    estado = np.ones(n_max)*int(T**4/n_max)
    # Definimos la energía del estado inicial
    E = E_Total(estado)
    
    

    # Definimos el bucle para los pasos
    for i in range(n_pasos):
        # Definimos el estado propuesto, que es el estado actual
        # con una partícula cambiada de estado
        estado_propuesto = estado.copy()


        # Elegimos un estado inicial aleatorio que tiene que tener al menos una partícula
        p_propuesto = 0
        while p_propuesto < 1:
            n = np.random.randint(n_max)
            p_propuesto = estado_propuesto[n]
        # Elegimos un estado final aleatorio que tiene que tener al menos una partícula
        p_propuesto = 0
        while p_propuesto < 1:
            m = np.random.randint(n_max)
            p_propuesto = estado_propuesto[m]

        # Cambiamos una partícula del estado inicial al final
        estado_propuesto[n] -= 1
        estado_propuesto[m] += 1

        # Calculamos la energía del estado propuesto
        E_propuesto = E_Total(estado_propuesto)

        # Calculamos la diferencia de energía entre el estado propuesto y el actual
        dE = E_propuesto - E

        # Si la energía del estado propuesto es menor que la del estado actual
        # aceptamos el estado propuesto
        if dE < 0:
            estado = estado_propuesto
            E = E_propuesto

        # Si la energía del estado propuesto es mayor que la del estado actual
        # aceptamos el estado propuesto con una probabilidad dada por la distribución de Boltzmann
        else:
            p = np.exp(-dE/T)
            if np.random.rand() < p:
                estado = estado_propuesto
                E = E_propuesto

        
    # Devolvemos los estados, las energías y la energía promedio
    return estado

# %%
particulas = metropolis(10, 4000, n_max=1000)

plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.plot(particulas)
plt.subplot(1,2,2)
plt.plot(lista_E)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 particulas = metropolis(0.0001, 4000, n_max=1000)
#       3 plt.figure(figsize=(20,10))
#       4 plt.subplot(1,2,1)
#
# Cell In[102], line 39, in metropolis(T, n_pasos, n_max)
#      37 # Elegimos un estado inicial aleatorio que tiene que tener al menos una partícula
#      38 p_propuesto = 0
# ---> 39 while p_propuesto < 1:
#      40     n = np.random.randint(n_max)
#      41     p_propuesto = estado_propuesto[n]
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.plot(particulas[-1])
plt.subplot(1,2,2)
plt.plot(lista_E)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 3
#       1 for p in particulas:
#       2     clear_output(wait=True)
# ----> 3     plt.plot(p)
#       4     plt.show()
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\pyplot.py:3575, in plot(scalex, scaley, data, *args, **kwargs)
#    3567 @_copy_docstring_and_deprecators(Axes.plot)
#    3568 def plot(
#    3569     *args: float | ArrayLike | str,
#    (...)
#    3573     **kwargs,
#    3574 ) -> list[Line2D]:
# -> 3575     return gca().plot(
#    3576         *args,
#    3577         scalex=scalex,
#    3578         scaley=scaley,
#    3579         **({"data": data} if data is not None else {}),
#    3580         **kwargs,
#    3581     )
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\pyplot.py:2525, in gca()
#    2523 @_copy_docstring_and_deprecators(Figure.gca)
#    2524 def gca() -> Axes:
# -> 2525     return gcf().gca()
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\figure.py:1658, in FigureBase.gca(self)
#    1648 """
#    1649 Get the current Axes.
#    1650
#    (...)
#    1655 whether `.pyplot.get_fignums()` is empty.)
#    1656 """
#    1657 ax = self._axstack.current()
# -> 1658 return ax if ax is not None else self.add_subplot()
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\figure.py:782, in FigureBase.add_subplot(self, *args, **kwargs)
#     780         args = tuple(map(int, str(args[0])))
#     781     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 782     ax = projection_class(self, *args, **pkw)
#     783     key = (projection_class, pkw)
#     784 return self._add_axes_internal(ax, key)
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\axes\_base.py:678, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     675 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     677 self._rasterization_zorder = None
# --> 678 self.clear()
#     680 # funcs used to format x and y - fall back on major formatters
#     681 self.fmt_xdata = None
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\axes\_base.py:1388, in _AxesBase.clear(self)
#    1386     self.cla()
#    1387 else:
# -> 1388     self.__clear()
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\axes\_base.py:1355, in _AxesBase.__clear(self)
#    1351 self.patch.set_transform(self.transAxes)
#    1353 self.set_axis_on()
# -> 1355 self.xaxis.set_clip_path(self.patch)
#    1356 self.yaxis.set_clip_path(self.patch)
#    1358 if self._sharex is not None:
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\axis.py:1112, in Axis.set_clip_path(self, path, transform)
#    1110 super().set_clip_path(path, transform)
#    1111 for child in self.majorTicks + self.minorTicks:
# -> 1112     child.set_clip_path(path, transform)
#    1113 self.stale = True
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\axis.py:240, in Tick.set_clip_path(self, path, transform)
#     237 @_api.rename_parameter("3.8", "clippath", "path")
#     238 def set_clip_path(self, path, transform=None):
#     239     # docstring inherited
# --> 240     super().set_clip_path(path, transform)
#     241     self.gridline.set_clip_path(path, transform)
#     242     self.stale = True
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\artist.py:803, in Artist.set_clip_path(self, path, transform)
#     800 if transform is None:
#     801     if isinstance(path, Rectangle):
#     802         self.clipbox = TransformedBbox(Bbox.unit(),
# --> 803                                        path.get_transform())
#     804         self._clippath = None
#     805         success = True
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\patches.py:261, in Patch.get_transform(self)
#     259 def get_transform(self):
#     260     """Return the `~.transforms.Transform` applied to the `Patch`."""
# --> 261     return self.get_patch_transform() + artist.Artist.get_transform(self)
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\patches.py:760, in Rectangle.get_patch_transform(self)
#     757 else:
#     758     rotation_point = self.rotation_point
#     759 return transforms.BboxTransformTo(bbox) \
# --> 760         + transforms.Affine2D() \
#     761         .translate(-rotation_point[0], -rotation_point[1]) \
#     762         .scale(1, self._aspect_ratio_correction) \
#     763         .rotate_deg(self.angle) \
#     764         .scale(1, 1 / self._aspect_ratio_correction) \
#     765         .translate(*rotation_point)
#
# File c:\Users\franc\miniconda3\envs\notebooks\Lib\site-packages\matplotlib\transforms.py:1903, in Affine2D.__init__(self, matrix, **kwargs)
#    1900 if matrix is None:
#    1901     # A bit faster than np.identity(3).
#    1902     matrix = IdentityTransform._mtx
# -> 1903 self._mtx = matrix.copy()
#    1904 self._invalid = 0
#
# KeyboardInterrupt:
