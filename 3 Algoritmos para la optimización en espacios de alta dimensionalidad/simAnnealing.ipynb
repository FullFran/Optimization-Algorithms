# %%
from simAnnealing import simulatedAnnealing, ciudades
from tsp import metodo_vecino_cercano

# %%
import numpy as np 
np.random.seed(0)

inicial = ciudades(100)

sa = simulatedAnnealing(inicial, T0=1,Tf=0.001, coolingRate=0.9999)

sa.run(newRouteMethod='inverse')
print(sa.route)
# Out:
# Iteración 69075 de 69074
# Distancia total = 8.43, Temperatura = 0.001
# [ 0 68 18 22 72 59 58 78  5 97 60 80 69 65 25 14  1 53 67 93 20 40 24 32
#  99 83 63 66 98 27 30  7 86 23 47 38 39 79 95 29 42 91 28 50 64 56 94 57
#  70 87 84 31 43 85 48 21 89 37 49 33 34 26  4 35 36 92 61 19 10 82  9 81
#  51 74 44  6 11 55  3 71 88 54 96 13 73 75 77  8 41 17 12 76 90 46 15 52
#  45  2 62 16  0]
