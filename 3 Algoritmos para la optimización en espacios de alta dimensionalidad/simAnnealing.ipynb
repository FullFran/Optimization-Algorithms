# %%
from simAnnealing import simulatedAnnealing, ciudades

import numpy as np 
from time import time

# %%
np.random.seed(0)
inicial = ciudades(90)

sa = simulatedAnnealing(inicial, T0=1,Tf=0.001, coolingRate=0.9999)

inicio = time()
sa.run(newRouteMethod='inverse')
print("Tiempo de ejecución: ", time()-inicio)
# Out:
# Iteración 69075 de 69074
# Distancia total = 8.09, Temperatura = 0.001
# Tiempo de ejecución:  3.4725773334503174

# %%
np.random.seed(0)
sa = simulatedAnnealing(ciudades(30), T0=1,Tf=0.001, coolingRate=0.9999, stoopingcriteria=1000)

inicio = time()
sa.run(newRouteMethod='inverse')
print("Tiempo de ejecución: ", time()-inicio)
# Out:
# Iteración 44924 de 69074
# Distancia total = 5.11, Temperatura = 0.011
# Tiempo de ejecución:  2.4002022743225098
